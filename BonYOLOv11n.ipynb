# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QMUYhD3lwRG5HUiXVbaS")
project = rf.workspace("newpaper").project("my-paper")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 117.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 125.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-paper-1 in yolov11:: 100%|██████████| 3386/3386 [00:00<00:00, 5262.74it/s]

# %%
from ultralytics import YOLO

#load model
model = YOLO('yolo11n.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 425MB/s]

# %%
# Train the model with 2 GPU
results = model.train(data='/content/My-paper-1/data.yaml', epochs=100, hsv_h=0.015, hsv_s=0.7, hsv_v=0.5,imgsz=640,batch=32)
model.train(
    data="/content/My-paper-1/data.yaml",
    epochs=100,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.5,
    translate=-0.0,
    scale=0.5,
    fliplr=0.0,
    mosaic=0.0,
    erasing=0.0,
    auto_augment=None,
)
# Out:
# Ultralytics 8.3.165 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/confusion_matrix.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/confusion_matrix_normalized.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/BoxF1_curve.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/BoxPR_curve.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/BoxP_curve.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/BoxR_curve.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/labels.jpg", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/labels_correlogram.jpg", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/results.png", width=1000)

# %%
from IPython.display import Image
Image(filename=f"/content/runs/detect/train2/val_batch0_pred.jpg", width=1000)
